# %%
from bs4 import BeautifulSoup
import requests

url = 'https://bing.com/'
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    title_tag = soup.find('title')

    if title_tag:
        print(title_tag.get_text())
    else:
        print("find title tag failed")
else:
    print("failed to retrieve webpage, status code:", response.status_code)
# Out:
# Search - Microsoft Bing

# %%
url = 'https://www.bing.com/'

response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

first_link = soup.find('a')
print(first_link)
print("----------------------------")

first_link_url = first_link.get('href')
print(first_link_url)
print("----------------------------")

all_links = soup.find_all('a')
print(all_links)

print("----------------------------")
paragraph_text = soup.find('a').get_text()
all_text = soup.get_text()
print(all_text)


print("============================")
example_divs = soup.select('div.hpapp')
print(example_divs)
# Out:
# <a aria-controls="id_d" aria-haspopup="true" class="id_button linkBtn" data-clarity-mask="true" h="ID=SERP,5012.1" href="javascript:void(0)" id="id_l"><span aria-hidden="false" id="id_s">Sign in</span><div class="b_hide"> <span class="cbtn" data-appns="SERP" data-k="5063.1" data-wire="I;button_init;; |" id="52D11C_1_btn"><input aria-label="" name="submit" type="submit" value="Sign in"/></span></div><span aria-hidden="false" aria-label="Sign in" class="sw_spd id_avatar" id="id_a"></span><span aria-hidden="true" id="id_n" style="display:none"></span><img alt="Profile Picture" class="id_avatar sw_spd" data-alt="" id="id_p" src="..." style="display:none"/></a>
# ----------------------------
# javascript:void(0)
# ----------------------------
# [<a aria-controls="id_d" aria-haspopup="true" class="id_button linkBtn" data-clarity-mask="true" h="ID=SERP,5012.1" href="javascript:void(0)" id="id_l"><span aria-hidden="false" id="id_s">Sign in</span><div class="b_hide"> <span class="cbtn" data-appns="SERP" data-k="5063.1" data-wire="I;button_init;; |" id="52D11C_1_btn"><input aria-label="" name="submit" type="submit" value="Sign in"/></span></div><span aria-hidden="false" aria-label="Sign in" class="sw_spd id_avatar" id="id_a"></span><span aria-hidden="true" id="id_n" style="display:none"></span><img alt="Profile Picture" class="id_avatar sw_spd" data-alt="" id="id_p" src="..." style="display:none"/></a>, <a aria-controls="rewid-f" aria-expanded="false" aria-haspopup="true" aria-label="Microsoft Rewards" class="id_button tooltip linkBtn" data-priority="2" dir="ltr" h="ID=SERP,5020.1" href="javascript:void(0)" id="id_rh_w" role="button" tabindex="0"><div class="hp" data-content="..." data-rewards-widget="medallion" id="rh_rwm"></div></a>, <a aria-label="Microsoft Cashback" class="id_button hp reverse" h="ID=SERP,5025.1" href="/rebates/payouts" id="id_rbh" role="link" style="display:none"><span class="hp" id="id_rbc"></span><span class="rwds_svg hp" id="id_rb_icon"><svg fill="none" viewbox="0 0 21 16" width="21" xmlns="http://www.w3.org/2000/svg"><path d="m14.5 14.3.8.6-.8-.6Zm4-7.5.8-.7-.7.7Zm0 2.4-.7-.6.8.6ZM13 1v1-1Zm1.5.7-.8.7.8-.7ZM3 2h10V0H3v2Zm10.7.4 4 5L19.4 6l-4-5-1.6 1.3Zm4 6.2-4 5 1.6 1.3 4-5-1.5-1.3ZM13 14H3v2h10v-2ZM2 13V3H0v10h2Zm1 1a1 1 0 0 1-1-1H0a3 3 0 0 0 3 3v-2Zm10.7-.4a1 1 0 0 1-.7.4v2a3 3 0 0 0 2.3-1.1l-1.6-1.3Zm4-6.2c.4.3.4.9 0 1.2l1.6 1.3a3 3 0 0 0 0-3.8l-1.5 1.3ZM13 2c.3 0 .6.1.7.4L15.3 1A3 3 0 0 0 13 0v2ZM3 0a3 3 0 0 0-3 3h2c0-.6.4-1 1-1V0ZM9.4 9.8c0-.3 0-.5-.2-.6a2 2 0 0 0-.7-.5 15 15 0 0 1-1-.4l-.8-.5a2 2 0 0 1-.5-.7L6 6c0-.5.2-1 .7-1.4.4-.4 1-.7 1.6-.7V2.8H9V4c.7.1 1.2.4 1.6.8.4.5.5 1 .5 1.7H9.4c0-.4 0-.7-.2-.9a.7.7 0 0 0-.6-.3c-.2 0-.4.1-.5.3-.2.1-.2.3-.2.6 0 .2 0 .5.2.6.1.2.4.3.7.5.3 0 .7.2 1 .4l.7.5.5.7.2 1a2 2 0 0 1-.6 1.4c-.4.4-.9.6-1.6.7v1h-.8v-1c-.8-.1-1.4-.4-1.8-.8-.4-.5-.6-1-.6-1.8h1.8c0 .4 0 .7.2 1l.8.2c.3 0 .4 0 .6-.2l.2-.6Z"></path></svg></span></a>, <a aria-controls="id_hbfo" aria-expanded="false" aria-haspopup="true" aria-label="Settings and quick links" class="idp_ham hphbtop linkBtn" h="ID=SERP,5030.1" href="javascript:void(0)" id="id_sc" role="button" tabindex="0"></a>]
# ----------------------------
# Search - Microsoft BingSign in
# ============================
# [<div class="hpapp" id="hp_app"></div>]
